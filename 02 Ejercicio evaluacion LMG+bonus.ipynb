# %%
#crear clase #TiendaOnline. Ejercicio Lourdes Moya

class TiendaOnline:

    def __init__(self):
        self.inventario = [] # es una lista de diccionarios[{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40}
        self.ventas_totales = 0.0 #guarda un float.
        self.clientes = {} #formato diccionario: {'Cliente1': {'email': 'cliente1@email.com', 'compras': []},

    def agregar_producto (self,nombre,precio,cantidad):
        '''Agrega un producto al inventario o actualiza su cantidad si ya existe'''

        for elemento in self.inventario: #itero a través del inventario        
            if  elemento['nombre'] == nombre: #comparo si el nombre está ya creado.
                elemento['cantidad'] = cantidad #de ese producto, actualizo la cantidad por asignación directa.
                return print("Se ha actualizado la cantidad") #uso este return en el if para que salga de la función y termine.
                
        self.inventario.append({"nombre":nombre, "precio":precio,"cantidad":cantidad}) #NO ENTRA EN EL IF porque no existe, y la creo

    def ver_inventario (self):
        '''Muestra el inventario de productos con sus detalles.'''

        if len(self.inventario) > 0: #compruebo si hay elementos en el inventario.
            for elemento in self.inventario: #itero a través del inventario          
                print(f"Nombre: {elemento["nombre"]}, Precio: ${elemento["precio"]}, Cantidad: {elemento["cantidad"]}")

        else: #si no hay elementos, devuelvo mensaje.
            print("No hay elementos en el inventario.")


    def buscar_producto(self,nombre):
        '''Busca un producto en el inventario por nombre y muestra sus detalles si se encuentra'''
        if len(self.inventario) > 0: #compruebo si hay elementos en el inventario.

            for elemento in self.inventario: #itero a través del inventario   - por cada elemento (diccionario) en la lista de diccionarios.       
                if  elemento['nombre'] == nombre: #comparo si el producto está .
                    return print(f"Nombre: {elemento["nombre"]}, Precio: ${elemento["precio"]}, Cantidad: {elemento["cantidad"]}")
                
        return False #devuelvo false si no lo ha encontrado, para luego usarlo en otra función.
                
    def actualizar_stock(self, nombre, cantidad):
        '''Actualiza el stock de un producto en el inventario'''

        for elemento in self.inventario: #itero por cada elemento (diccionario) en la lista de diccionarios.       
            if  elemento['nombre'] == nombre: #comparo si el nombre está ya creado.
                elemento['cantidad'] = cantidad #de ese producto, actualizo la cantidad por asignación directa.
                return print("La cantidad ha sido actualizada en el stock")
        
        print("El producto no está en el inventario.")

    def eliminar_producto(self, nombre):
        '''Elimina un producto del inventario por nombre.'''

        for elemento in self.inventario: #itero por cada elemento (diccionario) en la lista de diccionarios.       
            if  elemento['nombre'] == nombre: #comparo si el nombre está ya creado.
                self.inventario.remove(elemento)
                return print (f"El elemento {nombre} ha sido eliminado")
            
        print("El producto no está en el inventario")

    def calcular_valor_inventario (self):
        '''Calcula y muestra el valor total del inventario.'''

        suma_total = 0 #defino la variable donde voy a guardar el cálculo.
        for elemento in self.inventario: #itero por cada elemento (diccionario) en la lista de diccionarios. 
            suma_total += (elemento["cantidad"]*elemento["precio"]) #de cada elemento, que multiplique cantidad y precio.
        

        return print(f"El total del inventario asciende a ${suma_total}")
    
    #BONUS
    def agregar_cliente (self,nombre,email):
        '''Agrega un nuevo cliente al registro de clientes.'''

        for value in self.clientes.keys(): #como solo necesito comparar el valor de la key para comprobar si ese cliente ya existe.
            
            if value == nombre: #compruebo si existe el cliente sacandome las keys del diccionario.
                return print("Existe ese cliente ya.")
            
        self.clientes.update({nombre:{"email":email}}) #uso setdefault para crear

    #BONUS  
    def ver_clientes(self):
        '''Muestra la lista de clientes registrados con sus nombres y correos electrónicos.'''

        print("A continuación se muestra cada cliente seguido de su e-mail:""\n")

        print("Nombre    : E-mail")
        print("-----------------")
        for k,v in self.clientes.items(): 
            print(k,":",v["email"]) #aqui voy imprimiendo la clave principal (cliente) con su value (email), aun no está compra.
    #BONUS
    def realizar_compra(self):
        '''Permite a un cliente realizar una compra seleccionando productos del inventario. '''

        costo_compra =0 #variable para calcular el total del carrito
        carrito = {} #para ir guardando los elementos en el carro
        print("Inventario actual: \n ---------------------------------------- \n")
        self.ver_inventario()

        while True:
        
            resp = input("Introduzca el nombre del producto que desea comprar o 'salir' para parar el proceso de compra")

            if resp == "salir":
                break    
            else:
                
                estado = self.buscar_producto(resp) 
                if estado != False:
                    
                    print("\n****Datos Compra****\nEl producto seleccionado es:", resp)    

                    cant = int(input("¿Cuántas cantidades quieres?")) ##control errores si no es número
                    
                    print("Cantidades requeridas:", cant)    
                    
                    for elemento in self.inventario: #recorro la lista de diccionarios

                        for k,v in elemento.items(): #recorro cada diccionario

                            if v == resp: ##aqui llego al elemento que ha elegido el cliente.

                                #print ("Hi",elemento["cantidad"]) #print control                           
                                if cant <=elemento["cantidad"]: #aqui compruebo que no me ha pedido + cantidades que existentes
                                    
                                    print("Precio unitario:",elemento["precio"])
                                    
                                    elemento["cantidad"] -= cant
                                    costo_compra += cant*elemento["precio"]
                                    carrito = {"Nombre":resp,"Cantidad":cant,"Precio":elemento["precio"],"Total":costo_compra}

                                else:
                                    print("La cantidad introducida no es correcta")
                                    pass
                
        #print(carrito.items())           
        return print(f"El costo total de la compra asciende a ${costo_compra}")

# %%
pccomponentes = TiendaOnline()

# %%
pccomponentes.__dict__
# Out:
# {'inventario': [], 'ventas_totales': 0.0, 'clientes': {}}

# %%
pccomponentes.agregar_producto("Teclado",5,6)

# %%
pccomponentes.inventario
# Out:
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 6}]

# %%
pccomponentes.agregar_producto("Teclado",5,10)
pccomponentes.inventario
# Out:
# Se ha actualizado la cantidad
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 10}]

# %%
pccomponentes.agregar_producto("Raton",1.5,20)
pccomponentes.inventario
# Out:
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 10},
#  {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 20}]

# %%
pccomponentes.agregar_producto("Raton",1.5,30)
pccomponentes.inventario
# Out:
# Se ha actualizado la cantidad
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 10},
#  {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30}]

# %%
pccomponentes.agregar_producto("Teclado",5,20)
pccomponentes.inventario
# Out:
# Se ha actualizado la cantidad
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 20},
#  {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30}]

# %%
pccomponentes.agregar_producto("Cable",1.2,15)
pccomponentes.agregar_producto("Soporte",31.20,7)

# %%
pccomponentes.ver_inventario()
# Out:
# Nombre: Teclado, Precio: $5, Cantidad: 20
# Nombre: Raton, Precio: $1.5, Cantidad: 30
# Nombre: Cable, Precio: $1.2, Cantidad: 15
# Nombre: Soporte, Precio: $31.2, Cantidad: 7

# %%
pccomponentes.buscar_producto("Raton")
# Out:
# Nombre: Raton, Precio: $1.5, Cantidad: 30

# %%
pccomponentes.buscar_producto("boli")
# Out:
# False

# %%
pccomponentes.agregar_producto("Monitor",150,5)
pccomponentes.inventario
# Out:
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 20},
#  {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30},
#  {'nombre': 'Cable', 'precio': 1.2, 'cantidad': 15},
#  {'nombre': 'Soporte', 'precio': 31.2, 'cantidad': 7},
#  {'nombre': 'Monitor', 'precio': 150, 'cantidad': 5}]

# %%
pccomponentes.__dict__
# Out:
# {'inventario': [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 20},
#   {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30},
#   {'nombre': 'Cable', 'precio': 1.2, 'cantidad': 15},
#   {'nombre': 'Soporte', 'precio': 31.2, 'cantidad': 7},
#   {'nombre': 'Monitor', 'precio': 150, 'cantidad': 5}],
#  'ventas_totales': 0.0,
#  'clientes': {}}

# %%
pccomponentes.buscar_producto("Monitor")
# Out:
# Nombre: Monitor, Precio: $150, Cantidad: 5

# %%
pccomponentes.buscar_producto("Hola")
# Out:
# False

# %%
pccomponentes.actualizar_stock("Monitor",6)
pccomponentes.inventario
# Out:
# La cantidad ha sido actualizada en el stock
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 20},
#  {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30},
#  {'nombre': 'Cable', 'precio': 1.2, 'cantidad': 15},
#  {'nombre': 'Soporte', 'precio': 31.2, 'cantidad': 7},
#  {'nombre': 'Monitor', 'precio': 150, 'cantidad': 6}]

# %%
pccomponentes.actualizar_stock("Lonitor",6)
pccomponentes.inventario
# Out:
# El producto no está en el inventario.
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 20},
#  {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30},
#  {'nombre': 'Cable', 'precio': 1.2, 'cantidad': 15},
#  {'nombre': 'Soporte', 'precio': 31.2, 'cantidad': 7},
#  {'nombre': 'Monitor', 'precio': 150, 'cantidad': 6}]

# %%
pccomponentes.agregar_producto("Lonitor",6,1)
pccomponentes.inventario
# Out:
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 20},
#  {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30},
#  {'nombre': 'Cable', 'precio': 1.2, 'cantidad': 15},
#  {'nombre': 'Soporte', 'precio': 31.2, 'cantidad': 7},
#  {'nombre': 'Monitor', 'precio': 150, 'cantidad': 6},
#  {'nombre': 'Lonitor', 'precio': 6, 'cantidad': 1}]

# %%
pccomponentes.eliminar_producto("Lonitor")
pccomponentes.inventario
# Out:
# El elemento Lonitor ha sido eliminado
# [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 20},
#  {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30},
#  {'nombre': 'Cable', 'precio': 1.2, 'cantidad': 15},
#  {'nombre': 'Soporte', 'precio': 31.2, 'cantidad': 7},
#  {'nombre': 'Monitor', 'precio': 150, 'cantidad': 6}]

# %%
pccomponentes.calcular_valor_inventario()
# Out:
# El total del inventario asciende a $1281.4

# %% [markdown]
# * AQUI EMPIEZA EL BONUS

# %%
pccomponentes.agregar_cliente("Carrefour","car@gmail.com")
pccomponentes.clientes
# Out:
# {'Carrefour': {'email': 'car@gmail.com'}}

# %%
pccomponentes.agregar_cliente("Mercadona","mer@gmail.com")
pccomponentes.clientes
# Out:
# {'Carrefour': {'email': 'car@gmail.com'},
#  'Mercadona': {'email': 'mer@gmail.com'}}

# %%
pccomponentes.agregar_cliente("Carrefour","car@gmail.com")
pccomponentes.clientes
# Out:
# Existe ese cliente ya.
# {'Carrefour': {'email': 'car@gmail.com'},
#  'Mercadona': {'email': 'mer@gmail.com'}}

# %%
pccomponentes.agregar_cliente("Mercadona","mer@gmail.com") #pruebo a agregar el mismo para saber si va bien la función
pccomponentes.clientes
# Out:
# Existe ese cliente ya.
# {'Carrefour': {'email': 'car@gmail.com'},
#  'Mercadona': {'email': 'mer@gmail.com'}}

# %%
pccomponentes.agregar_cliente("Lidl","lidl@gmail.com")

# %%
pccomponentes.agregar_cliente("Aldi","aldi@gmail.com")

# %%
pccomponentes.clientes #hago esto para comprobar que el formato que he realizado es el que piden en el ejercicio.
# Out:
# {'Carrefour': {'email': 'car@gmail.com'},
#  'Mercadona': {'email': 'mer@gmail.com'},
#  'Lidl': {'email': 'lidl@gmail.com'},
#  'Aldi': {'email': 'aldi@gmail.com'}}

# %%
pccomponentes.ver_clientes()
# Out:
# A continuación se muestra cada cliente seguido de su e-mail:
#
# Nombre    : E-mail
# -----------------
# Carrefour : car@gmail.com
# Mercadona : mer@gmail.com
# Lidl : lidl@gmail.com
# Aldi : aldi@gmail.com

# %%
estado = pccomponentes.buscar_producto("boli")

print(estado)
# Out:
# False

# %%
pccomponentes.realizar_compra()
# Out:
# Inventario actual:
#  ----------------------------------------
#
# Nombre: Teclado, Precio: $5, Cantidad: 20
# Nombre: Raton, Precio: $1.5, Cantidad: 30
# Nombre: Cable, Precio: $1.2, Cantidad: 15
# Nombre: Soporte, Precio: $31.2, Cantidad: 7
# Nombre: Monitor, Precio: $150, Cantidad: 6
# El costo total de la compra asciende a $0

# %%
pccomponentes.ver_inventario()
# Out:
# Nombre: Teclado, Precio: $5, Cantidad: 20
# Nombre: Raton, Precio: $1.5, Cantidad: 30
# Nombre: Cable, Precio: $1.2, Cantidad: 15
# Nombre: Soporte, Precio: $31.2, Cantidad: 7
# Nombre: Monitor, Precio: $150, Cantidad: 6

# %% [markdown]
# * Hacia abajo son pruebas del código de arriba

# %%
diccionario1 = [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40},{'nombre': 'Pantalon', 'precio': 15, 'cantidad': 50}]

# %%
print (diccionario1)

for item in diccionario1:   
    for key,value in item.items():
        if "Camisa" == value:
            item['cantidad'] = 30

print (diccionario1)
# Out:
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40}, {'nombre': 'Pantalon', 'precio': 15, 'cantidad': 50}]
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 30}, {'nombre': 'Pantalon', 'precio': 15, 'cantidad': 50}]

# %%
print(pccomponentes.clientes["Mercadona"])
for elemento in pccomponentes.clientes:
    print(elemento)
# Out:
# {'email': 'mer@gmail.com'}
# Carrefour
# Mercadona
# Lidl
# Aldi

# %%
for k,v in pccomponentes.clientes.items():
    print(k,v)
# Out:
# Carrefour {'email': 'car@gmail.com'}
# Mercadona {'email': 'mer@gmail.com'}
# Lidl {'email': 'lidl@gmail.com'}
# Aldi {'email': 'aldi@gmail.com'}

# %%
for k,v in pccomponentes.clientes.items():
    print(k,v["email"])
# Out:
# Carrefour car@gmail.com
# Mercadona mer@gmail.com
# Lidl lidl@gmail.com
# Aldi aldi@gmail.com

# %%
array_productos = [ ("Procesador", 329.99, 2), ("GPU", 389.50, 1), ("SSD", 109.99, 2), ("RAM", 74.90, 4), 
                   ("Placa", 189.00, 1), ("Fuente", 92.40, 2), ("Refrigeracion", 149.95, 1), ("Caja", 79.99, 1), 
                   ("Router", 59.99, 2), ("Switch", 45.50, 3) ]


for i in array_productos:
    pccomponentes.agregar_producto(i[0],i[1],i[2])


pccomponentes.__dict__
#pccomponentes.ver_inventario()
# Out:
# {'inventario': [{'nombre': 'Teclado', 'precio': 5, 'cantidad': 20},
#   {'nombre': 'Raton', 'precio': 1.5, 'cantidad': 30},
#   {'nombre': 'Cable', 'precio': 1.2, 'cantidad': 15},
#   {'nombre': 'Soporte', 'precio': 31.2, 'cantidad': 7},
#   {'nombre': 'Monitor', 'precio': 150, 'cantidad': 6},
#   {'nombre': 'Procesador', 'precio': 329.99, 'cantidad': 2},
#   {'nombre': 'GPU', 'precio': 389.5, 'cantidad': 1},
#   {'nombre': 'SSD', 'precio': 109.99, 'cantidad': 2},
#   {'nombre': 'RAM', 'precio': 74.9, 'cantidad': 4},
#   {'nombre': 'Placa', 'precio': 189.0, 'cantidad': 1},
#   {'nombre': 'Fuente', 'precio': 92.4, 'cantidad': 2},
#   {'nombre': 'Refrigeracion', 'precio': 149.95, 'cantidad': 1},
#   {'nombre': 'Caja', 'precio': 79.99, 'cantidad': 1},
#   {'nombre': 'Router', 'precio': 59.99, 'cantidad': 2},
#   {'nombre': 'Switch', 'precio': 45.5, 'cantidad': 3}],
#  'ventas_totales': 0.0,
#  'clientes': {'Carrefour': {'email': 'car@gmail.com'},
# ...
